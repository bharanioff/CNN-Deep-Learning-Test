# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Dataset/credit_card.csv")

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %%
df.head(7)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 3                    0.00    205.788017             0.083333
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
# 6                  688.38      0.000000             1.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
# 5                    0.000000                          0.583333
# 6                    1.000000                          1.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
# 5                0.000000                 0              8        1800.0
# 6                0.000000                 0             64       13500.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12
# 5  1400.057770       2407.246035          0.000000      12
# 6  6354.314328        198.065894          1.000000      12

# %%
#HISTOGRAM
import matplotlib.pyplot as plt
fig=df.hist(figsize=(10,12))
plt.show()

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
#HEATMAP
import seaborn as sns
sns.heatmap(df.corr(),linewidths=5.0, annot=True)
plt.show()

# %%
df.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
df.shape
# Out:
# (8950, 18)

# %% [markdown]
# Q2. Perform the following Exploratory Data Analysis tasks:

# %% [markdown]
# a. Missing Value Analysis

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# MINIMUM_PAYMENTS                    313
# CREDIT_LIMIT                          1
# CUST_ID                               0
# BALANCE                               0
# PRC_FULL_PAYMENT                      0
# PAYMENTS                              0
# PURCHASES_TRX                         0
# CASH_ADVANCE_TRX                      0
# CASH_ADVANCE_FREQUENCY                0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_FREQUENCY                   0
# CASH_ADVANCE                          0
# INSTALLMENTS_PURCHASES                0
# ONEOFF_PURCHASES                      0
# PURCHASES                             0
# BALANCE_FREQUENCY                     0
# TENURE                                0
# dtype: int64

# %%
df.MINIMUM_PAYMENTS.mode()[0]
df.MINIMUM_PAYMENTS.fillna(df.MINIMUM_PAYMENTS.mode()[0],inplace=True)
df.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.CREDIT_LIMIT.mode()[0]
df.CREDIT_LIMIT.fillna(df.CREDIT_LIMIT.mode()[0],inplace=True)
df.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df=df.drop(['CUST_ID'],axis=1)

# %%
df=df.drop_duplicates()

# %% [markdown]
# b. Outlier Treatment using the Z-score method

# %%
import numpy as np
column=df.columns.values

# %%
mean = np.mean(df)
std = np.std(df)
print("Mean:\n",mean)
print("\n")
print("Standard Deviation:\n",std)
# Out:
# Mean:
#  BALANCE                             1564.474828
# BALANCE_FREQUENCY                      0.877271
# PURCHASES                           1003.204834
# ONEOFF_PURCHASES                     592.437371
# INSTALLMENTS_PURCHASES               411.067645
# CASH_ADVANCE                         978.871112
# PURCHASES_FREQUENCY                    0.490351
# ONEOFF_PURCHASES_FREQUENCY             0.202458
# PURCHASES_INSTALLMENTS_FREQUENCY       0.364437
# CASH_ADVANCE_FREQUENCY                 0.135144
# CASH_ADVANCE_TRX                       3.248827
# PURCHASES_TRX                         14.709832
# CREDIT_LIMIT                        4494.282473
# PAYMENTS                            1733.143852
# MINIMUM_PAYMENTS                     844.452407
# PRC_FULL_PAYMENT                       0.153715
# TENURE                                11.517318
# dtype: float64
#
#
# Standard Deviation:
#  BALANCE                             2081.415590
# BALANCE_FREQUENCY                      0.236891
# PURCHASES                           2136.515413
# ONEOFF_PURCHASES                    1659.795184
# INSTALLMENTS_PURCHASES               904.287592
# CASH_ADVANCE                        2097.046713
# PURCHASES_FREQUENCY                    0.401348
# ONEOFF_PURCHASES_FREQUENCY             0.298319
# PURCHASES_INSTALLMENTS_FREQUENCY       0.397426
# CASH_ADVANCE_FREQUENCY                 0.200110
# CASH_ADVANCE_TRX                       6.824265
# PURCHASES_TRX                         24.856260
# CREDIT_LIMIT                        3638.443420
# PAYMENTS                            2894.902017
# MINIMUM_PAYMENTS                    2332.766947
# PRC_FULL_PAYMENT                       0.292483
# TENURE                                 1.338256
# dtype: float64

# %% [markdown]
# c. Deal with correlated variables

# %%
df.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# CREDIT_LIMIT                      0.531296           0.095931   0.356977
# PAYMENTS                          0.322802           0.065008   0.603264
# MINIMUM_PAYMENTS                  0.397997           0.131576   0.095840
# PRC_FULL_PAYMENT                 -0.318959          -0.095082   0.180379
# TENURE                            0.072692           0.119776   0.086288
#
#                                   ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# BALANCE                                   0.164350                0.126469
# BALANCE_FREQUENCY                         0.104323                0.124292
# PURCHASES                                 0.916845                0.679896
# ONEOFF_PURCHASES                          1.000000                0.330622
# INSTALLMENTS_PURCHASES                    0.330622                1.000000
# CASH_ADVANCE                             -0.031326               -0.064244
# PURCHASES_FREQUENCY                       0.264937                0.442418
# ONEOFF_PURCHASES_FREQUENCY                0.524891                0.214042
# PURCHASES_INSTALLMENTS_FREQUENCY          0.127729                0.511351
# CASH_ADVANCE_FREQUENCY                   -0.082628               -0.132318
# CASH_ADVANCE_TRX                         -0.046212               -0.073999
# PURCHASES_TRX                             0.545523                0.628108
# CREDIT_LIMIT                              0.319735                0.256515
# PAYMENTS                                  0.567292                0.384084
# MINIMUM_PAYMENTS                          0.050294                0.134071
# PRC_FULL_PAYMENT                          0.132763                0.182569
# TENURE                                    0.064150                0.086143
#
#                                   CASH_ADVANCE  PURCHASES_FREQUENCY  \
# BALANCE                               0.496692            -0.077944
# BALANCE_FREQUENCY                     0.099388             0.229715
# PURCHASES                            -0.051474             0.393017
# ONEOFF_PURCHASES                     -0.031326             0.264937
# INSTALLMENTS_PURCHASES               -0.064244             0.442418
# CASH_ADVANCE                          1.000000            -0.215507
# PURCHASES_FREQUENCY                  -0.215507             1.000000
# ONEOFF_PURCHASES_FREQUENCY           -0.086754             0.501343
# PURCHASES_INSTALLMENTS_FREQUENCY     -0.177070             0.862934
# CASH_ADVANCE_FREQUENCY                0.628522            -0.308478
# CASH_ADVANCE_TRX                      0.656498            -0.203478
# PURCHASES_TRX                        -0.075850             0.568430
# CREDIT_LIMIT                          0.303997             0.119833
# PAYMENTS                              0.453238             0.103464
# MINIMUM_PAYMENTS                      0.140780             0.006228
# PRC_FULL_PAYMENT                     -0.152935             0.305802
# TENURE                               -0.068312             0.061506
#
#                                   ONEOFF_PURCHASES_FREQUENCY  \
# BALANCE                                             0.073166
# BALANCE_FREQUENCY                                   0.202415
# PURCHASES                                           0.498430
# ONEOFF_PURCHASES                                    0.524891
# INSTALLMENTS_PURCHASES                              0.214042
# CASH_ADVANCE                                       -0.086754
# PURCHASES_FREQUENCY                                 0.501343
# ONEOFF_PURCHASES_FREQUENCY                          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY                    0.142329
# CASH_ADVANCE_FREQUENCY                             -0.111716
# CASH_ADVANCE_TRX                                   -0.069088
# PURCHASES_TRX                                       0.544869
# CREDIT_LIMIT                                        0.295059
# PAYMENTS                                            0.243537
# MINIMUM_PAYMENTS                                   -0.027248
# PRC_FULL_PAYMENT                                    0.157531
# TENURE                                              0.082466
#
#                                   PURCHASES_INSTALLMENTS_FREQUENCY  \
# BALANCE                                                  -0.063186
# BALANCE_FREQUENCY                                         0.176079
# PURCHASES                                                 0.315567
# ONEOFF_PURCHASES                                          0.127729
# INSTALLMENTS_PURCHASES                                    0.511351
# CASH_ADVANCE                                             -0.177070
# PURCHASES_FREQUENCY                                       0.862934
# ONEOFF_PURCHASES_FREQUENCY                                0.142329
# PURCHASES_INSTALLMENTS_FREQUENCY                          1.000000
# CASH_ADVANCE_FREQUENCY                                   -0.262958
# CASH_ADVANCE_TRX                                         -0.169207
# PURCHASES_TRX                                             0.529975
# CREDIT_LIMIT                                              0.060794
# PAYMENTS                                                  0.085551
# MINIMUM_PAYMENTS                                          0.032113
# PRC_FULL_PAYMENT                                          0.250087
# TENURE                                                    0.073275
#
#                                   CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# BALANCE                                         0.449218          0.385152
# BALANCE_FREQUENCY                               0.191873          0.141555
# PURCHASES                                      -0.120143         -0.067175
# ONEOFF_PURCHASES                               -0.082628         -0.046212
# INSTALLMENTS_PURCHASES                         -0.132318         -0.073999
# CASH_ADVANCE                                    0.628522          0.656498
# PURCHASES_FREQUENCY                            -0.308478         -0.203478
# ONEOFF_PURCHASES_FREQUENCY                     -0.111716         -0.069088
# PURCHASES_INSTALLMENTS_FREQUENCY               -0.262958         -0.169207
# CASH_ADVANCE_FREQUENCY                          1.000000          0.799561
# CASH_ADVANCE_TRX                                0.799561          1.000000
# PURCHASES_TRX                                  -0.131168         -0.066157
# CREDIT_LIMIT                                    0.132608          0.149713
# PAYMENTS                                        0.183192          0.255278
# MINIMUM_PAYMENTS                                0.100678          0.111297
# PRC_FULL_PAYMENT                               -0.249773         -0.169784
# TENURE                                         -0.133372         -0.043421
#
#                                   PURCHASES_TRX  CREDIT_LIMIT  PAYMENTS  \
# BALANCE                                0.154338      0.531296  0.322802
# BALANCE_FREQUENCY                      0.189626      0.095931  0.065008
# PURCHASES                              0.689561      0.356977  0.603264
# ONEOFF_PURCHASES                       0.545523      0.319735  0.567292
# INSTALLMENTS_PURCHASES                 0.628108      0.256515  0.384084
# CASH_ADVANCE                          -0.075850      0.303997  0.453238
# PURCHASES_FREQUENCY                    0.568430      0.119833  0.103464
# ONEOFF_PURCHASES_FREQUENCY             0.544869      0.295059  0.243537
# PURCHASES_INSTALLMENTS_FREQUENCY       0.529975      0.060794  0.085551
# CASH_ADVANCE_FREQUENCY                -0.131168      0.132608  0.183192
# CASH_ADVANCE_TRX                      -0.066157      0.149713  0.255278
# PURCHASES_TRX                          1.000000      0.272902  0.370832
# CREDIT_LIMIT                           0.272902      1.000000  0.421876
# PAYMENTS                               0.370832      0.421876  1.000000
# MINIMUM_PAYMENTS                       0.098787      0.126800  0.129049
# PRC_FULL_PAYMENT                       0.162066      0.055695  0.112138
# TENURE                                 0.121874      0.139222  0.106136
#
#                                   MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# BALANCE                                   0.397997         -0.318959  0.072692
# BALANCE_FREQUENCY                         0.131576         -0.095082  0.119776
# PURCHASES                                 0.095840          0.180379  0.086288
# ONEOFF_PURCHASES                          0.050294          0.132763  0.064150
# INSTALLMENTS_PURCHASES                    0.134071          0.182569  0.086143
# CASH_ADVANCE                              0.140780         -0.152935 -0.068312
# PURCHASES_FREQUENCY                       0.006228          0.305802  0.061506
# ONEOFF_PURCHASES_FREQUENCY               -0.027248          0.157531  0.082466
# PURCHASES_INSTALLMENTS_FREQUENCY          0.032113          0.250087  0.073275
# CASH_ADVANCE_FREQUENCY                    0.100678         -0.249773 -0.133372
# CASH_ADVANCE_TRX                          0.111297         -0.169784 -0.043421
# PURCHASES_TRX                             0.098787          0.162066  0.121874
# CREDIT_LIMIT                              0.126800          0.055695  0.139222
# PAYMENTS                                  0.129049          0.112138  0.106136
# MINIMUM_PAYMENTS                          1.000000         -0.135086  0.060070
# PRC_FULL_PAYMENT                         -0.135086          1.000000 -0.016486
# TENURE                                    0.060070         -0.016486  1.000000

# %% [markdown]
# Q3.
# Perform dimensionality reduction using PCA such that the 95% of the variance is explained

# %%
x=df.drop(['TENURE'],axis=1)
y=df['TENURE']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.60,test_size=0.40,random_state=47)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((5370, 16), (3580, 16), (5370,), (3580,))

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
predicted_y=model.predict(x_test)
predicted_y
# Out:
# array([12, 12, 12, ..., 12, 12, 12])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_test,predicted_y)
# Out:
# 0.8466480446927375

# %%
confusion_matrix(y_test,predicted_y)
# Out:
# array([[   4,    1,    2,    0,    0,    0,   62],
#        [   2,    1,    1,    0,    0,    0,   63],
#        [   1,    2,    0,    0,    0,    0,   85],
#        [   0,    0,    0,    0,    0,    0,   80],
#        [   1,    0,    0,    0,    0,    0,   82],
#        [   1,    1,    0,    0,    0,    0,  152],
#        [   7,    1,    4,    0,    1,    0, 3026]])

# %%
z=classification_report(y_test,predicted_y)
print(z)
# Out:
#               precision    recall  f1-score   support
#
#            6       0.25      0.06      0.09        69
#            7       0.17      0.01      0.03        67
#            8       0.00      0.00      0.00        88
#            9       0.00      0.00      0.00        80
#           10       0.00      0.00      0.00        83
#           11       0.00      0.00      0.00       154
#           12       0.85      1.00      0.92      3039
#
#     accuracy                           0.85      3580
#    macro avg       0.18      0.15      0.15      3580
# weighted avg       0.73      0.85      0.78      3580
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#PCA
from sklearn.decomposition import PCA
pca=PCA(n_components=0.95)

# %%
y_test,predicted_y, new_predicition
# Out:
# (6492    12
#  4006    12
#  1439    12
#  5898     6
#  1031    12
#          ..
#  4920    12
#  571     12
#  4637    12
#  8506     9
#  2805    12
#  Name: TENURE, Length: 3580, dtype: int64,
#  array([12, 12, 12, ..., 12, 12, 12]),
#  array([12, 12, 12, ..., 12, 12, 12]))

# %%
from sklearn.metrics import accuracy_score
new_acc=accuracy_score(new_predicition,y_test)
new_acc
# Out:
# 0.8488826815642458

# %% [markdown]
# Q4.
# Find the optimum value of k for k-means clustering using the elbow method. Plot the elbow curve

# %%
import sklearn
from sklearn.cluster import KMeans

# %%
#Elbow geaph
import matplotlib.pyplot as plt
plt.plot(range(1,7),wcss)

# %%
#Sum of cluster squares
wcss=[]
for i in range(1,7):
  kmeans=KMeans(n_clusters=i, 
                init='k-means++', 
                n_init=10, 
                max_iter=300, 
                tol=0.0001,  
                verbose=0, 
                random_state=None, 
                copy_x=True,  
                algorithm='auto')
  kmeans.fit(df)
  wcss.append(kmeans.inertia_)

# %% [markdown]
# Q5.
# Find the optimum value of k for k-means clustering using the silhouette score method and specify the number of observations in each cluster using a bar plot

# %%
import sklearn.metrics as metrics
for i in range(4,9):
    kmeans=KMeans(n_clusters=i,
                  init="k-means++",
                  random_state=200)
    kmeans.fit(df)
    labels=kmeans.labels_
    print ("Silhouette score for k(clusters) = "+str(i)+" is "
           +str(metrics.silhouette_score(df,
                                         labels,
                                         metric="euclidean",
                                         sample_size=1000,
                                         random_state=200)))
import matplotlib.pyplot as plt
from yellowbrick.cluster import SilhouetteVisualizer

fig, ax = plt.subplots(2, 2, figsize=(10,10))
for i in [2, 3, 4, 5]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='Dark2', ax=ax[q-1][mod])
    visualizer.fit(x)
# Out:
# Silhouette score for k(clusters) = 4 is 0.38213617623234636
# Silhouette score for k(clusters) = 5 is 0.35989213869773073
# Silhouette score for k(clusters) = 6 is 0.3786654083397706
# Silhouette score for k(clusters) = 7 is 0.35478473187393456
# Silhouette score for k(clusters) = 8 is 0.3616414301738822

# %% [markdown]
# # **Part II: Deep Learning**

# %% [markdown]
# Q1.
# Print the total number of positive and negative sentiments.

# %%
import pandas as pd
df=pd.read_csv("/content/Sentiment.csv")

# %%
positive=0
negative=0
for i in df['sentiment']:
  if i =='Positive':
    positive=positive+1
  elif i=='Negative':
    negative=negative+1
print("Positive_Sentiments", positive)
print("Negative_Sentiments", negative)
# Out:
# Positive_Sentiments 2236
# Negative_Sentiments 8493

# %% [markdown]
# Q2.
# Build a sequential LSTM model to predict positive and negative sentiments.

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
corpus = []
for i in range(0, 1000):
    review = re.sub('[^a-zA-Z]', ' ', 
                    df['text'][i])
    review = review.lower()
    review = review.split()
    ps = PorterStemmer()
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['rt nancyleegrahn everyon feel climat chang question last night exactli gopdeb',
#  'rt scottwalk catch full gopdeb last night scott best line second walker http co zsff',
#  'rt tjmshow mention tamir rice gopdeb held cleveland wow',
#  'rt robgeorg carli fiorina trend hour debat men complet gopdeb say',
#  'rt danscavino gopdeb w realdonaldtrump deliv highest rate histori presidenti debat trump http co',
#  'rt gregabbott tx tedcruz first day rescind everi illeg execut action taken barack obama gopdeb foxnew',
#  'rt warriorwoman like happi heard go moder anymor gopdeb megynkelli http',
#  'go msnbc live thomasarobert around pm et gopdeb',
#  'deer headlight rt lizzwinstead ben carson may brain surgeon perform lobotomi gopdeb',
#  'rt nancyosborn last night debat prove gopdeb batsask badassteachersa tbat http co g ggji bjd',
#  'jgreendc realdonaldtrump fair billclinton own phrase gopdeb',
#  'rt waynedupreeshow woke tweet gopdeb best line night via govmikehuckabe http co ov hxhicv',
#  'read famili comment great gopdeb http co giagjpygxz',
#  'rt arcticfox rt allenwestrepub dear jebbush gopdeb notamistak http co ttfg kycd',
#  'rt pattonoswalt love scott walker mark harmon romant rival summer school look gopdeb',
#  'hey chrischristi exploit tragedi polit gain rudygiulianigop thing gopdeb',
#  'rt carolcnn donaldtrump fire comment women peterbeinart sl schaeffer iwf myrkig weigh gopdeb http',
#  'rt johncardillo guess speak time gopdeb foxnew moder time http co wsut c lx',
#  'reason comment funni case ignor gop tcot reason govern work peopl gopdeb',
#  'rt pamelagel huckabe pay transgend surgeri soldier sailor airmen make countri safer ha gopdeb',
#  'rt chucknelli cruz class amp truth get vote gopdeb',
#  'rt mchamric rt teatraitor gopdeb still clown show glad head clown trump help destroy gop http co nwgx g jwr',
#  'rt erinmallorylong hate plan parenthood women hate plan parenthood women gopdeb',
#  'rt thekevinryd gopdeb vine dabulldawg http co xkxvdradc',
#  'rt mrpooni fox news tri convinc us young black american worri isi polic terror gopdeb http co',
#  'gopdeb rank worst perform rubio kasich christi bush trump cruz walker paul huckabe carson',
#  'rt thebaxterbean scott walker abort ban allow rapist father sue emot distress http co rhmvgumuir gopdeb badger',
#  'rt feministabul competit move far gay right women right wors ever g',
#  'rt mch rt teatraitor gopdeb still clown show glad head clown trump help destroy gop http co pri qpcwfu',
#  'rt hillaryclinton watch gopdeb bet feel like donat democrat right http co pglqcqqgop http co qp e',
#  'fbhw go need borrow train horn next gopdeb littl bell wimpi hornmeansyouredon',
#  'rt lisavikingstad ted cruz gopdeb like ted cruz bed keep confusingli sad look face refus',
#  'first gopdeb social media reaction http co x kuvskltf',
#  'socialmedia first gopdeb social media reaction http co ogoyfnyikj',
#  'rt winesdaypodcast updat foxnew tech failur gopdeb http co fgglf j hu http co zw dkuozi',
#  'rt amymek torch pass gt candycrowley longer famou polit assassin congratul megynkelli u wi',
#  'rt stockwizard trump carson ticket would win landslid realdonaldtrump seanhann anncoult republican potu trump',
#  'rt kvxrdashian jeb bush obama fault brother obama clean mess brother made gopdeb http',
#  'rt ali fox news gopdeb primari voter none wiser polici plan folk put forth journal',
#  'rt itsashlyperez listen fetti wap pack true american gopdeb doesthishashtagexpir',
#  'rt mgell trump cross shrug emoji presid busi lego movi gopdeb',
#  'rt jamellemybel meanwhil white hous gopdeb http co nouuut hkq',
#  'rt rowdygentleman plan gopdeb drink game right rowdi gentleman',
#  'rt brownblaz pleas rt kkkorgop gopdeb http co yaqyac uv',
#  'trump think critic misogynist remark polit correct problem nope pervas sexism problem gopdeb',
#  'rt lekarmasucr gopdeb handl blacklivesmatt http co zgdi lpct',
#  'rt palmaceiahom goal foxnew last night take trump pave way rino like bush kasich gopdeb',
#  'rt philstockworld live chat room gopdeb trump futur spi nonfarmpayrol job netflix http co k sf rq http',
#  'danscavino gopdeb w realdonaldtrump deliv highest rate histori presidenti debat trump fox say thank',
#  'rt gov tweet govmikehuckabe gopdeb moment say purpos militari kill peopl break thing tran servicememb',
#  'rt ariannahuff best worst gopdeb http co yki j hho',
#  'rt megynkelli chrisstirewalt big moment randpaul vs chrischristi realdonaldtrump reaction women question kellyfil',
#  'rt stylemom question hell women amp bodi part even debat foh stop wtf gopdeb',
#  'rushlimbaugh american get behead oversea megynkelli worri whether realdonaldtrump call rosi donnel fat gopdeb',
#  'rt chucknelli defend foxnew far fair balanc last night name call juvenil gopdeb',
#  'rt theskysgoneout non christian gopdeb god question underlin littl anyon realli care religi minor chri',
#  'rt bipartisan gopdeb respons blacklivesmatt pathet http co ismxbrrm h',
#  'rt factcheckdotorg jebbush said cut fl tax b includ cut estat tax mandat feder law gopdeb ht',
#  'rt mydaughtersarmi dear gop want stop abort gopdeb http co rbl ipx',
#  'rt karrattipaul join isi sign death warrant sign tedcruz next presid us gopdeb wakeupamerica cruzcrew htt',
#  'rt p tu gopdeb close statement http co nlillso',
#  'rt amymek statu singl broke foxnew last night goodby megynkelli bretbaier amp chri wallac gopdeb http',
#  'rt frankluntz gopdeb focu grouper said favor view trump saw posit http',
#  'rt holli rene made first donat carlyfiorina impress gopdeb perform fiorina http co jlfhfvz st',
#  'rt thejimhugh want stop send foreign aid place burn flag start berkeley gopdeb',
#  'rt frankthorpnbc rand paul eye roll chri christi gopdeb http co hf qsowd',
#  'rt johnkasich scrap presid iran deal iran get nuke kasich us gopdeb http co trzxonlzf',
#  'tri decid earli come back twitter fulltim gonna wait closer elect gopdeb may hook',
#  'rt mspackyetti donald trump campaign reveal import thing twitter troll real peopl vote scare eve',
#  'rt bipartisan say worri trump never elect need rememb elect georg bush twice gopdeb http',
#  'fox news gopdeb agenda promot carli never mention fire hp fiorina amp run trump race http co k eujdfo',
#  'rt hlllari oh one thing anyon hear anyth afford child care work famili last night gopdeb',
#  'rt naughtybeyotch rt allenwestrepub dear jebbush gopdeb notamistak http co wqnsupspkc',
#  'marthamaccallum billhemm gopdeb bill martha team first debat nd debat ambush',
#  'countri go hell megyn kelli foxnew attack trump war women gopdeb',
#  'rt franklin graham st gopdeb encourag see sever candid express faith god son jesu christ http c',
#  'rt snarkydemo donaldtrump said polit correct cours trumpspeak let face huge asshol',
#  'rt bipartisan messag gopdeb candid http co wfk cmvgin',
#  'rt davidcicillin worst episod apprentic ever seen gopdeb',
#  'rt govmikehuckabe luntz line go almost reach almost never happen dial research gopdeb htt',
#  'rt lolhayley purpos militari kill peopl break thing someth actual man run presid said',
#  'wonder could get republican parti pay liver transplant play mtaibbi gopdeb drink game last night',
#  'rt brandondhowel great way start friday carlyfiorina carlyfiorina gopdeb http co ai cuz',
#  'rt tedcruz elect first day presid rescind everi illeg unconstitut execut order enact pre oba',
#  'rt ronni k donald trump gopdeb like http co jcuirk u',
#  'rt bruneski upstair put kid bed mani question climat chang miss gopdeb gopclowncar',
#  'todd akin plan parenthood sting backfir republican gopdeb standwithpp http co ekxpfkthqn',
#  'rt learjett hey foxnew let republican digest gopdeb allow crazi dwstweet trash gop ladysandersfarm http',
#  'rt thebaxterbean watch donald trump receiv enorm applaus horribl misogynist gopdeb answer http co r e tpotd http',
#  'favorit twitter respons gopdeb last night http co iqcdrcdlm http co tdma vlm',
#  'even though super conserv report actual like megyn kelli interview style amp great gopdeb',
#  'rt kingsth gopdeb debat seri minut opportun avoid answer question one candid',
#  'rt melissagracey credit joke goe someon els funni gopdeb http co icredssplr',
#  'rt reinc simpli incred http co apxm ao jf last night gopdeb doubl previou record watch primari debat',
#  'rt katethoma liter true watch gopdeb amp got lousi hangov http co cxch x',
#  'rt fl dreamer haha littl saa voxdotcom morn toward realdonaldtrump factcheck gopdeb http co daectmllaj',
#  'rt texascruzn rt allenwestrepub dear jebbush gopdeb notamistak http co z vufjzlw',
#  'rt zellieimani peopl saw person vs saw tv gopdeb http co qlgsxrh hw',
#  'rt thebaxterbean marco rubio told face candid yesterday anti gay bigotri http co eiuettlf gopdeb ht',
#  'rt cariisi none made trump look place foolish yet think done cri think agai',
#  'rt akbarjenkin mayb gop got piven amp cloward confus pinkard amp bowden think steal car kevinbak kevinmkr',
#  'great time watch gopdeb last night http co qcmxmu mlp',
#  'rt jrehl gopdeb donald trump say time polit correct call women fat pig save',
#  'rt theonlyadult potu one peopl tv might next one rip everyth gopdeb http co',
#  'think realdonaldtrump caught surpris first question never abl recov equilibrium gopdeb',
#  'rt kirahoffi foxnew web stream mobil app fail gopdeb surpris http co tkpesooezt',
#  'rt johnkasich john kasich help ohioan creat new job america gopdeb http co kbzfbjyp c',
#  'pleas help maryknol sister replac window convent http co fdgxg vv cathol gofundm trcot gopdeb',
#  'rt carlyfiorina gopdeb largest audienc yet chip help us keep http co nzync jrx http',
#  'trump said jebbush true gentleman amp start violent ing gopdeb',
#  'rt cameronesposito ugh guy ever shut much respect women gopdeb',
#  'rt snarkydemo gopdeb teach us futur presid trump america probabl safe except attack',
#  'rt congoboy go long tire elect season shockingli ill inform candid gopdeb http co vtk k txi',
#  'rt amymek god bless republican parti mani great candid thedemocrat even find one marcorubio gopdeb',
#  'rt johnkasich miracl happen grow opportun grow job gopdeb http co lnqhdgtudk',
#  'rt mattyiceaz scott walker even carri state gopdeb',
#  'rt xlnb black peopl need anymor indic republican hate us peep gopdeb http co bh chsi eh',
#  'rt smethani sure god told run tooth fairi agre teletubbi vote ye gopdeb',
#  'rt palmaceiahom trump told megyn kelli go hell foxnew gopdeb',
#  'rt palmaceiahom caller rush limbaugh show lost respect fox news foxnew gopdeb',
#  'rt realdonaldtrump stinger inc realdonaldtrump megynkelli behaviour gopdeb astonishingli bias',
#  'republican debat econom rubio win bush falter huckabe exagger http co molloaqhwq gopdeb knowmorenotless gpnaplang',
#  'rt jamesvis huh half clinton chariti went clinton http co bvwrosgwal copolit hillari stophillari uniteb',
#  'rt kraig u gopdeb order take trump wonder fox news one took order serious heidil rn',
#  'rt diegouk democrat watch gopdeb last night http co v wjok vm p ctl topprog tcot tlot',
#  'rt amymek owe realdonaldtrump huge thank expos world megynkelli chri wallac amp frankluntz true rhino',
#  'rt thebaxterbean scott walker lie say wi budget surplu actual b deficit http co vvmxzkxlkr gopdeb http',
#  'right last heard sensand women could give birth child chang gopdeb http co hkcefp hf',
#  'rt pattonoswalt receiv word god soup sandwich crazi gopdeb',
#  'rt frankconniff fox news gopdeb interview candid take gop talk point feed',
#  'rt lesliemac murder black ppl fine unborn black babi goplog gopdeb',
#  'rt hillaryclinton miss jon stewart alreadi gopdeb jonvoyag h',
#  'rt charlottelaw chri christi realli stand gopdeb',
#  'rt libertyjibbet hey realdonaldtrump know whine unfair question carlyfiorina grow set ya gopd',
#  'pro life watch hour abort last night gopdeb forkedtongu iseeorangepeopl',
#  'rt danscavino megynkelli fail american peopl tonight tri make histori destroy realdonaldtrump kellyfai',
#  'rt edstetz btw mix polit religion get polit gopdeb',
#  'rt teammarco marco nail abort must protect life gopdeb http co nn j',
#  'megynkelli bretbaier foxnew wtf chri wallac attack trump bankruptci give rubio softbal gopdeb',
#  'obvious get memo seersuckerthursday gopdeb http co lzagrrtzfl',
#  'rt vh honestli donald trump type petti last night gopdeb gt http co qxdoemfuqo http co mcr lrjh h',
#  'rt tuxcedocat republican dope say take us back day one never see one day white hous gopdeb',
#  'trump gloat abt buy gop dem pol amp bid billionair caricatur myacash gopdeb http co spmu csic',
#  'rt peddoc go carli go carli go carli carlyfiorina carli gopdeb flyovercultur leahr steph maydnusa http co',
#  'rt daeneri listen gopdeb like http co jrcuqdafu',
#  'rt scorpionspriest best moment gopdeb last night rand tell christi go get anoth hug obama',
#  'rt johnfugelsang miss either gopdeb need know struggl american unlimit war',
#  'rt pfikac jebbush verg greatest time aliv world washington hold us back mysa txlege',
#  'rt drmartyfox trump win drudg debat poll landslid tedcruz gopdeb pjnet http co yuh j qqha http',
#  'rt siteroi governorperri fight back abt immigr q say border porou must fix first',
#  'summari gopdeb statu quo shit show',
#  'rt thepatriot debbi block tweeter question dem debat schedul http co gxna toqaq gopdeb dwstweet http co kxikf',
#  'rt sallykohn hey look men stand stage argu get control women bodi choic gopdeb',
#  'rt thebaxterbean rubio budget rais middleclass tax add deficit cut investmenttax http co nuvsaf gopdeb ht',
#  'rt chrisjzullo last night gopdeb saw bunch rich old despot zero solut nation problem un',
#  'rt nancyosborn gopdeb batsask badassteachersa tbat debat learn noth new http co vmtnri xev http co mt',
#  'rt rfhkerri think peopl qualifi unfollow gopdeb',
#  'rt bipartisan ben carson spoke scienc gopdeb neiltyson like http co byooh n',
#  'real illeg alien gopdeb farrakhan immigr mexican bor http co lklffn lfi via youtub',
#  'gopdeb talk head put debat talk head tell us debat went mayb wast time watch',
#  'rt steel donaldtrump plaza casino teddybear plush tuxedo http co qhttx pldg coolstuff gopdeb http co qjunzji',
#  'trump right megynkelli realli need studi matthew vers gopdeb http co ygnprhiehv',
#  'rt ac donaldtrump memor gopdeb moment right ac http co kdnhgj ry http co hz gwe',
#  'gopdeb one pictur http co wmmucjuqju',
#  'rt maureenjohnson think women sleep curs shed open field properti',
#  'think god pretti fair guy ben carson neurosurgeon belief modern day taxat base ancient book gopdeb',
#  'rt nancyleegrahn cheer gopdeb audienc aftertrump defiantli name rosi woman call fat pig voic',
#  'blackliv matter appar republican candid presid http co rfevfwsxx foxnew uniteblu gopdeb',
#  'overal main thing learn gopdeb straight white men matter',
#  'usfre life thought seanhann best post gopdeb interview night gave chanc straighten posit',
#  'rt johnkasich hey realdonaldtrump still look chip check http co dy knz gopdeb',
#  'megynkelli bretbaier chriswallac america critic ur perform gopdeb b c u realli bad job moder',
#  'govmikehuckabe luntz line go almost reach almost never happen dial research gopdeb rig',
#  'rt oftenimprud wish could teach teenag girl love much donald trump love gopdeb',
#  'rt amymek conserv peopl without network gopdeb foxnew',
#  'rt bhowl come talk climat chang anyon even seen california right gopdeb debatewithberni',
#  'rt travisconsidin governorperri gopdeb perform review reel http co qurozbku perri',
#  'rt chrisjzullo last night could rais hand spoil billionair oligarch racist religi',
#  'gopdeb teamdrbencarson realbencarson wow brilliant cool calm amp collect empow',
#  'rt soopermexican ted cruz appreci emphat sarcast air quot megan kelli gopdeb',
#  'rt benjamminwalk circumst men dictat abort right women st centuri better',
#  'rt danscavino gopdeb winner drudg k realdonaldtrump time k realdonaldtrump foxsd realdonaldtrump http',
#  'rt joeprich megynkelli chide candycrowley go object moder activ particip gopdeb http',
#  'gopdeb foxnew realdonaldtrump call billclinton two time slut stand statement',
#  'rt renomarki never watch kellyfil gopdeb question pander dwstweet make rate http',
#  'imho gopdeb winner marcorubio kasich donaldtrump loser scottwalk randpaul bencarson other complet forgett',
#  'rt johnkasich smaller govt ohio govern payrol smaller decad http co igfif j tt gopdeb http co',
#  'rt zellieimani twitter user takeov gopdeb hashtag drag gop candid http co lmznompfmw kkkorgop http co ewez c',
#  'rt jebbush challeng teacher union beat way go jeb http co imgwdrl g gopdeb',
#  'rt billyeichn thank watch gopdeb tonight julieklausn blast write',
#  'theblaz real war women realdonaldtrump megynkelli rushlimbaugh gopdeb anncoult',
#  'rt governorperri governorperri fire debat perform http co armjn vwpg gopdeb perri tcot',
#  'rt blowtici pro life republican like gopdeb http co bioxoplejn',
#  'rt governorperri icymi governorperri border secur illeg immigr gopdeb perri tcot http co nk',
#  'rt allthingsflynn trump vs fox news conflict quit conundrum like personif greed vs hate root',
#  'rt carlyfiorina know extraordinari nation gopdeb',
#  'rt laxnoreo meanwhil white hous gopdeb http co mf ixfovc',
#  'rubio still prefer see point critic opportun inconsist gopdeb',
#  'realdonaldtrump ever tell megynkelli go wait car bad attitud suggest waronwomen gopdeb',
#  'rt thetexasphoenix fire governorperri fire debat perform http co w w sz gopdeb perri',
#  'rt play dad settl gopdeb http co w w e nboa',
#  'rt realdonaldtrump frankluntz get lot megynkelli hatemail tonight gopdeb total overr angri',
#  'liter true watch gopdeb amp got lousi hangov http co cxch xxq v robinmarti',
#  'jonvoyag half long gopdeb twice intellig',
#  'rt lisabloom singl question last night gopdeb urgent issu time climat chang',
#  'gopdeb foxnew amp gotcha question seem design elicit typic polit spin respons tlot',
#  'gopdeb promis made startup tech confer seem quit reason',
#  'rt roy roger knuckldraginsam gop realdonaldtrump yobynnad amen trump wakeupamerica gopdeb tcot stoprush http',
#  'rt carlyfiorina highest call leadership challeng statu quo amp unlock potenti other gopdeb carli',
#  'rt zzcrane watch donald trump bandwagon pass tlot tcot gopdeb http co wvqlsxgmcl',
#  'rt deray gopdeb began moder say million ppl discuss racial issu happen tho',
#  'rt feministabul noth like listen ten dude never need abort talk whether right',
#  'rt senwhitehous fox silenc koch billion singl question last night gopdeb climatechang denier mond',
#  'rt tyriquex republican rich care poverti america amp definit care bout poverti bla',
#  'offic chat gopdeb amp out flame liber polit geek probabl surpris',
#  'catch gopdeb lindseygrahamsc childish amp cheap move call billclinton amp hillaryclinton year old stori',
#  'rt tomhal thing could made last night gopdeb amus would cowbel morecowbel http co',
#  'rt kesgardn ted cruz attack republican gopdeb',
#  'rt governorperri icymi hell irand gopdeb perri tcot http co kqhjdjcgw',
#  'rt frankconniff hard say gopdeb berni hillari',
#  'rt larhunt donald trump win elect know biff stole almanac timelin gopdeb',
#  'rt carlyfiorina chip keep momentum go gopdeb carli http co w mtcmr ze',
#  'rt cenkuygur chri christi said work two year retir get ten thousand less paid',
#  'rt johnkasich john kasich readi lead join team clair http co dy knz gopdeb http co knwmideqti',
#  'rt edwrath biggest loser debat fox moder attack instead moder gopdeb',
#  'rt whitneyn trump yet give singl evid base answer direct question polici frighten gopdeb',
#  'way studio appear cnn discuss last night gopdeb tune',
#  'rt blkfeminst honestli think sometim guy forgot came womb kkkorgop gopdeb http co fo dxflf',
#  'rt grneyedmandi women shame women abort deserv shame soul self respect plannedparen',
#  'rt amandajogomez watch gopdeb look directli camera like offic',
#  'rt icaruspundit donald trump close statement everi dinner convers villag ever gopdeb',
#  'rt thexclass rich wage war poor die jean paul sartr gop foreign polici gopdeb',
#  'gopdeb saw candid complet miss mark race amp blacklivesmatt http co k nhdpue http co hlcqpxjzru',
#  'rt seabassthephish gop proud defeat teacher union even though want higher wage gopdeb',
#  'rt writeintrump obama better leav prayer rug behind oval offic get elect throw gopdeb',
#  'chucknelli foxnew got right gopdeb',
#  'rt mrskimcam trump said u stupid let vote presid wtf peopl gopdeb',
#  'excit johnkasich gopdeb kasich us republicandeb kasich wait year',
#  'rt chadpergram rep engel nd major jewish democrat announc opposit iran deal gopdeb follow schumer opposit',
#  'hey look feel donald trump sum one gif gopdeb http co zjwugwj hz',
#  'rt tommychong dude legal marijuana gopdeb',
#  'rt cberesniova learn gopdeb guy dad mailman jesu christ everyon run mate gop run',
#  'rt thebaxterbean marco rubio briefli back immigr reform privat berat dreamer http co qdt kt gopdeb http',
#  'rt damienfahey french kiss jesu christ everi candid gopdeb',
#  'gopdeb closingstat govmikehuckabe honest u def talk realdonaldtrump coz steal ur schtick',
#  'cnn msnbc new york time prais fox moder know moder fuck gopdeb',
#  'rt kesgardn trump lunat gopdeb',
#  'cruz class amp truth get vote gopdeb',
#  'rt kesgardn assclown reason anyon even talk illeg immigr keep dig donald gopdeb',
#  'rt berniesand tom hank final somebodi make sens gopdeb debatewithberni',
#  'rt southernhomo olivia pope would vote guy gopdeb',
#  'gop candid want reduc tax huckabe want legal prostitut drug tax gopdeb',
#  'rt kesgardn hi fox panel ask donald everi singl question hand shovel keep dig',
#  'rt josephkapsch hillaryclinton barackobama joebiden gopdeb http co yi qn hzh',
#  'gopdeb trump break record polish politician make love even http co tgowchxf x',
#  'rt berniesand oh movi trailer gopdeb debatewithberni',
#  'rt tacticaldiss salli kohn amp debbi wasserman schultz prais megyn kelli tonight tell everyth need',
#  'trump accessori women wear shoe gopdeb http co xz zc lt n',
#  'funniest line come fr republican peopl frustrat fed think govern work gopdeb',
#  'donald trump absolut nut entertain lol gopdeb',
#  'thehil top gop pundit pick gopdeb winner http co qpvju p sz http co jcdu qzjnj winner fox news loser usa',
#  'rt dykstradam candid went hillaryclinton time gopdeb remain silent issu affect us http',
#  'rt danscavino megynkelli tri show realdonaldtrump w foxnew tri take tri destroy happen kelli',
#  'rt gov tweet gopdeb moment realbencarson say public world answer waterboard',
#  'give e big ego gopdeb earn excel rhyme rump',
#  'passion gopdeb religiousupamovi',
#  'rt nro marcorubio got best review deserv read nreditori recap gopdeb gt http co stzw',
#  'rt ohnoshetwitnt wait see lannist kill next episod gopdeb',
#  'rt kesgardn brutal question assclown megan kelli lesson care tweet twitter gopdeb',
#  'rt tusk democrat watch gopdeb http co szicslm km',
#  'trump chang mind support partial birth abort friend chang mind abort amp great kid gopdeb',
#  'best close statement realbencarson gopdeb',
#  'rt chrischristi stop worri love amp start worri respect tellingitlik gopdeb http',
#  'rt lesleyabravanel trump sycoph want know megynkelli hidden agenda last night answer simpl call vagin',
#  'real gopdeb winner republican voter fox nation http co g iaz',
#  'donald trump realli nasti piec work hope disappear quickli gopdeb',
#  'rt amaraconda fetus unborn babi cluster cell stop shame peopl want abort gopdeb',
#  'rt mattkbh far away best tweet last night debatewithberni gopdeb http co gzdltyumnn',
#  'know chrischristi remind actor andi devin gopdeb http co xyy fxpjcd',
#  'rt pattonoswalt despit huckabe say alway make sure prostitut pimp pay fica pension gopdeb',
#  'rt bipartisan hillari clinton watch gopdeb like http co vokolq xp',
#  'foxnew great challeng candid gopdeb candid handl tough question could never b potu',
#  'rt k mcq say opposit megan kelli act like sjw tumblr whine femin sad gopdeb http c',
#  'rt conssista rightli frank rightli gopdeb http co cfasi',
#  'number time ronald reagan mention gopdeb damn high',
#  'rt pattonoswalt trump p c cultur suddenli even kid howl shit cave human gop',
#  'rt carljacksonshow bencarson great close oper brain worri skin color gopdeb',
#  'rt davant r women would offend trump misogyni certainli vote republican find new fake issu faux news',
#  'rt auntcol keep religion polit gopdeb',
#  'rt dianneg bought amp sold randpaul reiter point realdonaldtrump gopdeb',
#  'rt wilw boy bet mood clown car go tens jerk leav gopdeb',
#  'rt campeauelliot dr ben carson great job tonight love close statement realbencarson gopdeb',
#  'rt redheadandright meet new darl left megyn gotcha kelli gopdeb foxnew donaldtrump megynkelli',
#  'foxnewspolit behind fox debat anchor hash question gopdeb fail',
#  'anyon get trash play rollingston gopdeb drink game drinkinggam',
#  'donaldtrump donat u call favor year later sound like thegodfath potu that legal gopdeb gopclowncar',
#  'rt jedian ugh think actual peopl sit couch last night say ye ye reason gopdeb',
#  'rt barracudamama rt allenwestrepub dear jebbush gopdeb notamistak http co e smu hn j',
#  'rt kesgardn polit even partial ration trump campaign gop nomin end gopdeb',
#  'rt andrewhclark gaypatriot takeaway last night america deserv ben carson http co kjgfyypct gopdeb',
#  'rt chrisjzullo scott walker choos kill mother rather abort unborn embryo reason countri give us funni',
#  'uniteblu abort talk point gopdeb sinc ppsellsbabypart',
#  'rt k mcq close statement reminisc america longer exist ted kennedi immigr nation act g',
#  'rt lkwdcitizen make chri christi stop cleveland ice cream shop gopdeb http co v wvyfexx',
#  'rt maureenjohnson ted cruz go person take away telescop tri witch gopdeb',
#  'realdonaldtrump kill last night gopdeb glad care america makeamericagreatagain',
#  'rt youngblkrepub gopdeb excit anyth els tv past year',
#  'rt abbijacobson shiiiittt tough say make horni gopdeb',
#  'megynkelli ask realdonaldtrump poor question help bush poll hanniti gopdeb http co p iil n',
#  'bullrid olivianuzzi daveweigel gopdeb better thought though candid finess issu sound byte',
#  'rt thebaxterbean ye marco rubio actual said iraq invas mistak http co xrowkhymm gopdeb http co vjmjdm',
#  'rt thebaxterbean marco rubio vote unemploy benefit even though florida need http co uolsctj gopdeb ht',
#  'jebbush thought gopdeb rethink http co k hnbe jy',
#  'rt thejimhugh lot job avail bush serv term conserv commit suicid go',
#  'huh watch foxnew debat far moder particip better gopdeb',
#  'rt chicspolitico donald trump insult megynkelli women one man stage confront none worthi',
#  'rt jjauthor learjett wait megynkelli ask realdonaldtrump stop beat wife gopdeb http',
#  'rt andreatantaro last night watch outnumberedfnc got ericbol good stuff gopdeb',
#  'rt renomarki earth megynkelli aint gopdeb foxdeb megynkelli megynkellydebatequest http co yxhi',
#  'rt kesgardn rand paul land first haymak night gopdeb',
#  'rt tarasetmay come wilkowmajor pm live siriusxm patriot post gopdeb',
#  'republican like rosi donnel icymi frankluntz gopdeb debrief cbsthismorn http co nqiuiccolb',
#  'fff highlight week includ nationalunderwearday gopdeb jonvoyag offici worst week ever tgif',
#  'rt greenspaceguy thedailyshow jon stewart feel comfort w retir gopdeb solv problem person amp scientif htt',
#  'rt kesgardn cours assclown pledg run third parti candid gopdeb',
#  'paul krugman sum happend last night one two major parti gone deep end http co gkubem ge gopdeb',
#  'rt eqphoto rememb matter win gopdeb everyon watch lose alcoholpoison',
#  'rt anthonymarlow trump video cost time would manag realdonaldtrump gopdeb h',
#  'megynkelli disgrac last night gopdeb',
#  'rt proginosko predict final gopdeb donald trump tear missionimposs mask reveal smirk jon stewart',
#  'fallon jon stewart pleas come back alon http co iua hy uc gopdeb polit',
#  'rt bbcjonsopel midst gopdeb came big blow barackobama announc lead jewish democrat sen schumer b',
#  'rt kesgardn ted cruz angl slightli less looni version donald trump gopdeb',
#  'meet new darl left megyn gotcha kelli gopdeb foxnew donaldtrump megynkelli',
#  'rt toddstarn abort question disgust gopdeb',
#  'nytim cnn prais foxnew thought good job gopdeb good thing',
#  'rt texascruzn rt allenwestrepub rt oliverdarci debbi wasserman schultz statement gopdeb gop sole focus http',
#  'rt jstephencart hottak carli fiorina becam st tier candid yesterday otherwis gopdeb chang noth ancient',
#  'gopdeb lesson come month qualiti quantiti word amp time tangibl believ propsal http co yhvnoeinyi',
#  'cnn new york time prais foxnew moder know complet wrong gopdeb',
#  'rt lindasuhl first republican debat candid report card benshapiro gopdeb http co mfipucslg tcot http co zvhw',
#  'rt evanmcmurri accord gov retweet candid tweet gopdeb come republican http co cuv af',
#  'megynkelli display utmost author foxnew gopdeb critic say http co jbvwjtj http co mel jxm b',
#  'rt tusk one candid spoke trump mass deport plan amp one condemn racist comment latino forget',
#  'donald hero gopdeb http co zzflchjqo',
#  'rt gerryduggan kryptonian scienc council worri climat chang scari peopl gopdeb',
#  'withhold valuabl presidenti endors hear everyon point view nd amend gopdeb',
#  'rt arcticfox rt allenwestrepub rt oliverdarci debbi wasserman schultz statement gopdeb gop sole focus http',
#  'rt mikedruck ronald reagan never abort isi women need either basic everyon tonight gopdeb',
#  'rt patriotmom gt rick santorum say gay marriag constitut basi http co mauvifi oh gopdeb foxdeb tcot',
#  'rt gregabbott tx scottwalk everi part world hillaryclinton touch wors today truth gopdeb foxnew',
#  'chrischristi gopdeb last night candid answer question directli afraid take tough issu',
#  'best jab hillari clinton republican fox news debat gopdeb http co zeoiem p',
#  'rt govmikehuckabe fredbarn weeklystandard mike huckabe star luntz focu group show spoke feedback',
#  'watch primetim gopdeb afternoon think bencarson real winner quiet effect',
#  'rt toddstarn come gay marriag gotcha section gopdeb',
#  'rt jacki pepper jeb give seriou janet reno tonight gopdeb http co vxfi ms wg',
#  'boomer r smart know use internet gopdeb http co igp wwnzcu cosproject jpnet http co mt hetqx',
#  'rt govmikehuckabe china deal playground bulli punch face amp put ground b c re',
#  'rt ali lot republican facebook twitter timelin tick fox news run hatchet job debat gopdeba',
#  'defend foxnew far fair balanc last night name call juvenil gopdeb',
#  'rt catholiclisa hat ben carson use term use idiot hillari clinton secular progress movement gopd',
#  'megynkelli fox team talk minut gopdeb walker talk obviou goal ambush everyon pathet',
#  'rt johnamato actual agre andreatantaro someth said realdonaldtrump hurt gopdeb concur',
#  'rt donniewahlberg like ben carson brain mike huckabe heart marco rubio soul chri christi fight john kasich hope add carli fi',
#  'speed date new presid interest articl gopdeb http co qnti hdhr',
#  'rt bradbannon gop debat campaign preview rearview bradbannon linkedin http co n mko qqie uniteblu p potu',
#  'rt dykstradam gopdeb like super crappi cage fight bluster bumbl old wrinkl tucku clincher without ca',
#  'rt govmikehuckabe militari social experi purpos militari kill peopl break thing imwithhuck',
#  'rt bennydiego break tie winner gopdeb http co im nfxjia',
#  'tvmojo curiou miss rate tweet gopdeb',
#  'megynkelli gopdeb kelli role model speak prof friend rosi real woman carlyfiorina kelli poser',
#  'donald trump whatajok gopdeb',
#  'rt funnyordi feel like fox news tri cool parent let kid parti amp hous fire gopdeba',
#  'rt patriotmom unconscion foxnew moder ask candid except santorum foreign polici amp nat sec question',
#  'rt chipmark militari social experi purpos kill peopl break thing mike huckabe gopdeb',
#  'rt crissghoul pro life pro control pro religion pro never mother gopdeba',
#  'rt redstatejak solid debat tip take gander gop http co pufj dla gopdeb teaparti tcot tlot icon http co wpi',
#  'rt johnkasich creat job greatest moral purpos strengthen famili amp commun gopdeb http co xe',
#  'rt nevagphx carlyfiorina magnific first gopdeb support ted cruz potu would support run mate pot',
#  'woman support r parti pleas wake get inform gopdeb',
#  'kasich clear standout among gopdeb cannon fodder record contradict statement lgbt accept http co ynuckulnjv',
#  'primari still long way away favorit could chang hope see candid sound bite gopdeb',
#  'anti carlyfiorina unit clinton person destruct forc work sure gopdeb http co p dt tiy',
#  'rt govmikehuckabe presid end nation disgrac fail care vet sacrif countri gt http co',
#  'least honest gopdeb http co bo prpmx',
#  'rt marmel mother work nobodi gopdeb',
#  'rt newswrit american get behead oversea megynkelli worri whether realdonaldtrump call rosi donnel f',
#  'gopdeb real american idol elect audit whose consent count amp decis made http co bleobi r n',
#  'elect democraci polit debat entertain particularli sterl qualiti feder republ gopdeb',
#  'chrischristi randpaul american fear peopl live fear free liberti fear unamerican gopdeb',
#  'rt bennettcartoon glass slipper gopdeb gopprimari republicanfield http co fyhzzn qp',
#  'rt bj gopdeb carli fiorina domin social media even beat trump fox nation http co vueeverddi',
#  'rt rachelmartinart wonder gopdeb address actual solut climat chang clean energi debatewithberni',
#  'rt vivigold realdonaldtrump misogynist ignor xenophob greedi anoth proof money buy class gopdeb go',
#  'anti slaveri real illeg alien gopdeb farrakhan immigr amp mexican bor http co lklffn lfi via youtub',
#  'rt immigrannacion jebbush gopdeb usa serious would vote clown need cirnow ainf tntvote http co',
#  'rt waynedupreeshow disagre want gopdeb hit job realdonaldtrump calcul mute job sentedcruz realbencarso',
#  'actual agre andreatantaro someth said realdonaldtrump hurt gopdeb concur',
#  'r exot design diamond ring http co whr sl tp youtub http co djb fkj j gopdeb chemieunfal compton lion',
#  'rt govmikehuckabe let take america hope higher ground help gt http co tki smc imwithhuck gopdeb http',
#  'rt ambertoz got caught gopdeb felt like write joke biggest joke whole',
#  'rt joshcom jeb make want blow rail w wreck dad car gopdeb',
#  'keep religion polit gopdeb',
#  'second tier gopdeb particip would audienc debat berni sander',
#  'chri cristi abort absurd gopdeb',
#  'gopdeb im still vote blue http co azyupu oyd',
#  'eat lunch two old ladi discuss gopdeb give life shade shit outta christi trump',
#  'rt ali davi tonight gopdeb import remind guy think women carri case fetus',
#  'rt realbencarson may lord guid word tonight let wisdom thought gopdeb',
#  'rt thejimhugh note kasich question love gay marriag thebigdodg gopdeb',
#  'rt squintz gopdeb pretti much http co fhg fmg',
#  'rt palmaceiahom rush limbaugh megyn kelli know democrat candid would treat way megyn kelli treat trump foxnew',
#  'rt deray trump liter said donat politician call later get want liter said',
#  'rt itswillyferrel meanwhil back white hous gopdeb http co un gnnuhb',
#  'gopdeb none presidenti candid brought fuck gom jabbar mean least liven crazi',
#  'rt youhadonejob donald trump hair arriv earli republican parti presidenti debat gopdeb http co cqupkrybs',
#  'rt govmikehuckabe eloqu knew say believ say imwithhuck gopdeb http',
#  'retw emotientinc emot read technolog first amp analyz audienc reaction gopdeb http co dkbgxzqxhp',
#  'rt thebaxterbean fact checker prove scott walker liter lie often tell truth http co keoebnrwgu gopdeb ht',
#  'rt pattonoswalt want berniesand quietli walk onto stage five point palm explod heart hollow beast g',
#  'gopdeb debat good quit throw crap realdonaldtrump got substant candid handl gotcha question',
#  'rt brio clown even tackl climat chang mention inequ surpris gopdeb http',
#  'rt pattonoswalt go ask lenni kravitz peni one question disrespect gopdeb',
#  'watch gop debat last night saw trump donaldtrump gopdeb realdonaldtrump trumpforpresid',
#  'factcheck gopdeb http co n rubxxcv unsurpris massiv level lie truth stretch gener bullshitteri',
#  'wonder much tonight megynkelli show gopdeb foxnew',
#  'rt chooseliferac gopdeb never lose focu truli import issu defundpp amp praytoendabort http co oxiow yj',
#  'rt chicspolitico trump call megynkelli bimbo reprehens choos candid presid jerri spri',
#  'repeal word night gopdeb',
#  'rt rebleb mention gopdeb vote right climat chang gun violenc polic shoot student debt inequ',
#  'rt carlyfiorina almost time tune foxnew p edt gopdeb carli http co hev fe hhr',
#  'amaz degre commit run joke http co vpxxlxevhi gopdeb photobomb',
#  'rt govmikehuckabe foxnew focu group articul relat amp made lot good point imwithhuck gopdeb h',
#  'rt teatraitor gopdeb still clown show glad head clown trump help destroy gop http co qwtnpuir',
#  'rt braveconwarrior rt allenwestrepub dear jebbush gopdeb notamistak http co mgjn ver',
#  'gop want defundpp huckabe want legal prostitut drug gopdeb',
#  'favorit jeb line take teacher union beat sure empow kid disenfranchis one teach em gopdeb',
#  'rt britt ash current mood gopdeb http co gfsnedxeoj',
#  'newest b built like huckabe complain mean st ronni built gopdeb',
#  'rt waynedupreeshow mayb next kellyfil megynkelli go krauthamm year posit switch parti',
#  'rt g humbertson perri say would rather send carlyfiorina negoti iran john kerri gopdeb',
#  'fan foxnew megynkelli deserv better call bimbo ldonaldtrump job gopdeb uniteblu',
#  'excel post gop debat analysi friend rman limitgovt http co giuogvmnnc gopdeb',
#  'rt rachlwhitehurst tell bad cramp uteru tri flee countri watch gopdeb',
#  'rt kumailn realiz dawn us holi shit watch fox news gopdeb',
#  'hey realdonaldtrump know whine unfair question carlyfiorina grow set ya gopdeb',
#  'rt whoissizzl hillari spent gopdeb kim kany love see http co h ijxx http co kq nb',
#  'john kasich seem like decent guy shame drown looni gop gopdeb',
#  'rt feministabul feel trump gopdeb http co bkuz oiam',
#  'rt deray end bingo gopdeb http co xul qxp',
#  'chri christi said appoint u attorney sept actual appoint dec gopdeb http co gkqtnvk',
#  'chri christi fundament misunderstand th amend amp got own randpaul nsa http co xawzzrhvfi gopdeb',
#  'rt cmclymer fun fact parti super patriot singl candid stage serv day militari gopdeb',
#  'rt realalexjon realalexjon take twitter question gopdeb rd hr today show watch live pm ct http',
#  'rt kelkulu surpris twist kevin spacey appear stage tap ring podium push candid front train',
#  'exjon essmailpatricia cuffymeh trump support threaten take nerf ball home hard hit gopdeb trumpspeepeehurt',
#  'rt wagnergirl thank tedcruz speak govermentcartel makeamericagreatagain securethebord gopdeb http co',
#  'rt mattyiceaz ironi watch men debat women right choos gopdeb',
#  'first gopdeb social media reaction http co ih ksywl',
#  'real illeg alien america gopdeb farrakhan immigr amp mexican bor http co lklffn lfi via youtub',
#  'candid realli like hug one word defin one gopdeb http co rghrenzewi http co rzzzg p',
#  'rt imfabul assum guy boo gay soldier time opportun aris rsg gopdeb http',
#  'rt hrc johnkasich said love daughter gay vote record say otherwis gopdeb http co qwnqmblz',
#  'rt marmel mother work mother work mother work nobodi mention mother nobodi gopdeb',
#  'gopdeb affordablecareact flaw constitut repeal http co ozmidag w jpnet http co iu jnb fte',
#  'rt iamthedenk gopdeb tonight realli wanna see cut best promo',
#  'john oliv new jon stewart wait coverag gopdeb jonvoyag',
#  'rt littleladycassi gopdeb love fiorina smart point',
#  'rt cati warren remind less percent plannedparenthood deal abort debat tell',
#  'rt k mcq gop base voter target leftist terror campaign year amp gop establish relentlessli manipul',
#  'rt milesorionfeld entertain trump throw sever head crowd gopdeb',
#  'check candid best line first gopdeb http co ji j pnsi tcot alpolit',
#  'rt thatchrisgor realli sure presid ted cruz would make excel marvel villain gopdeb tedcruz marvel',
#  'rt zellieimani debat terror expect anyon bring white supremacist organ engag terror kkkor',
#  'thedailyshow jon stewart feel comfort w retir gopdeb solv problem person amp scientif http co vovjmtwu j',
#  'rt artem klyushin highlight last night gopdeb http co e lnt tql',
#  'donald trump reagan con man deliv good thinkprogress gopdeb http co lhmrkxwvci',
#  'gmadawni rt rhondawatkgwyn imwithhuck gopdeb th ccot tcot teaparti pjnet http co ba kwluu',
#  'gop primari tourney ncaa bracket format narrow candid final gopdeb realclearnew http co ocetmht ba',
#  'gopdeb offer singl solut salient issu',
#  'gopdeb presidenti candid stuck thing presidenti electr sharpen',
#  'emot read technolog first amp analyz audienc reaction gopdeb http co ltqgcdi w http co bywwedhvgg',
#  'rt annebayefski sentedcruz american leav amp join isi lose passport come home gopdeb',
#  'rt jgalt love cruz introduc bill strip citizenship american join isi gopdeb http co mylrlv u e',
#  'joshbretow dude total thought pftcomment pic gopdeb photo shop guess hahaha righteou',
#  'rt anergo teacher serious trump danger whole world gopdeb',
#  'rt joehudsonsmal would realli let mother die rather abort serious ask presidenti hope',
#  'jeb bush defund plan parenthood proud deni thousand women access life save healthcar gopdeb',
#  'rt richarddeitsch frankbruni gopdeb writer top game http co jt alyui',
#  'rt pamelagel know rand strategi go trump got noth lose nowher anyway gopdeb',
#  'credit credit due shock shock trump cogent health care debat respons gopdeb http co mdfg ufaz',
#  'rt pattonoswalt conclud debat pleas welcom koch brother choos ideolog broodmar whore stab',
#  'rt colmorrisdavi amus hear men chose serv militari talk tough use peopl kid backup b',
#  'god go like co presid someth gopdeb eleventhdebat',
#  'rt redstatejak pay seriou watch someon grill egomaniac bulli interview gopdeb kellyfil http',
#  'kind glad get watch gopdeb yesterday better mental health',
#  'bipartisan well technic suprem court said gopdeb',
#  'mayb gop got piven amp cloward confus pinkard amp bowden think steal car kevinbak kevinmkrus gopdeb',
#  'rt amaraconda swear god anoth ci white man speak abort like know like pregnant gopdeb',
#  'fun game watch gopdeb replac word god koch bro reagan',
#  'elianabenador politicalshort samlov love andybry ebenjon mjgranger gopdeb trump selfish amp immatur power',
#  'gopdeb tweet athon think gain polit satirist follow lost teacher peep u win',
#  'rt fakedansavag kelli call women like fat pig dog disgust anim trump rosi donnel crow',
#  'rt ethicistforhir ten rich narcissist spout nihilist applaus line debat zeitgeist gopdeb',
#  'realli thought marcorubio solid perform last night gopdeb',
#  'smartest amp wisest man room last night bare got speak time littl salti gopdeb realbencarson',
#  'highlight video part iowa gopdeb parti last night full video http co zaq p qy http co b meukti',
#  'rt govmikehuckabe govmikehuckabe good night well tonight bretbaier imwithhuck gopdeb http co fn gmknq',
#  'rt writeintrump hey megan kelli ask kelli osbourn attack week work gopdeb',
#  'rt megynkelli tedcruz get power respons frankluntz focu group kellyfil gopdeb',
#  'god amp religion import elect religion play part decis make countri gopdeb',
#  'pose awkward hell work stiff natur kinda like gopdeb last night piss pat',
#  'rt goddessjaz discuss racist polic violenc finish type tweet gopdeb kkkorgop',
#  'rt rickcanton cruzcrew outsid alway tell truth honor commit gopdeb http co wheorxlcid',
#  'rt mspeopl jebbush tell hang em neck wing parti gopdeb kkkorgop http co fgwctd bb',
#  'sick gopdeb analysi wait sunday night iamjohnoliv lastweektonight lock make us lol',
#  'dont care think dont time pc respect women someth natur gopdeb',
#  'rt zellieimani ben carson one seem see care say racism doesnt exist kkkorgop gopdeb http',
#  'rt bipartisan get readi play gopdeb bingo http co rwgi dozx',
#  'coincid watch gopdeb unless cabl',
#  'rt redstatejak newsflash need knock peg megynkelli gopdeb kellyfil pjnet tcot megynkelli http',
#  'rt writeintrump gopdeb parti rand paul get sinc bar allow poodl',
#  'megynkelli think high rate foxnew gopdeb hate break honey realdonaldtrump',
#  'walk restaur last night even meal came feel sick stomach gopdeb',
#  'winner gopdeb far concern carlyfiorina johnkasich realbencarson marcorubio',
#  'rt alexisinnh two debat one winner carli http co piewa jccc carli gopdeb',
#  'gopdeb debat stage fill liar traitor doubl talk cheater deceiv misogynist stunk high heaven',
#  'play gopdeb survivor carlyfiorina bobbyjind replac chrischristi amp govmikehuckabe http co yfajhhivkg gannett',
#  'rt writeintrump anyon know megan kelli piss gopdeb pretti sure never marri',
#  'rt jayedilla surpris surpris govmikehuckabe think tran life social experi gopdeb',
#  'rt boblonsberri biggest loser gopdeb megynkelli chri wallac cynic arrog condescend game show host',
#  'rt megynkelli crazi day fun night exhaust week moment gopdeb fire big event http co vwg',
#  'rt thecjpearson call gopdeb cruztovictori http co p jem cfpw',
#  'billhemm ask romney moment pass would ask reagan worst question gopdeb',
#  'rt pattonoswalt talk hilari like john wick love gopdeb',
#  'strang god told vote gopdeb http co b sr mmalx',
#  'rt thebaxterbean rick santorum said best gopdeb http co j rbjeylv',
#  'trumptast gopdeb',
#  'rt mattyiceaz us economi ad job juli must result job kill obamacar republican talk last nig',
#  'carlyfiorina one biggest winner thursday night without even step prime time stage cnn gopdeb',
#  'gopdeb sure fun game one wacko finger big red button http co ndgrhvpb',
#  'everyon feel climat chang question last night exactli gopdeb',
#  'rt bodybyn absolut author kate law leader parti block kate law cruzcrew gopdeb http co',
#  'rt nadamoo everyon talk gopdeb meanwhil debat banana pb amp chocol cooki n cream http',
#  'trump told megyn kelli go hell foxnew gopdeb',
#  'bring democrat debat alreadi pleas amp thank gopdeb',
#  'everyon still talk great job realbencarson gopdeb last night articul good point made',
#  'rt tedcruz need new command chief stand enemi credibl gopdeb cruzcrew',
#  'chri christi pro life republican never apolog pro life http co mdmned lgq gopdeb http co oljo mj',
#  'chri christi pro life republican never apolog pro life http co aiartbsmtx gopdeb http co psfvoyi j',
#  'rt bg jindal fiorina two stand open act gopdeb',
#  'jkarsh pffft sinc fox care ladi viewer plu megyn sole goal gopdeb come winner',
#  'rt jfreewright last time heard stupid amp idiot use liber debat race presid kindergarten',
#  'laugh huck mention pimp get em mike imwithhuck gopdeb th ccot tcot http co lmoh w',
#  'rt dwstweet messag spin room univis winner gopdeb tonight next year democrat nomine http',
#  'rt brianstelt overnight gopdeb household rate biggest gop debat rate http co vhl',
#  'rt ben elder donald trump rand paul tonight gopdeb http co jv yfov xz',
#  'gopdeb great theatric perform broadway',
#  'omg megynkelli fox news fan clinton fan amaz job last night impress qs gopdeb',
#  'although occasion dick realdonaldtrump sure know keep polit debat aliv excit gopdeb',
#  'rt laurengreenberg okay kill peopl militari okay get abort rape victim',
#  'rt nymag hillari clinton spent gopdeb night kardashian http co gklccjobi http co xrsj rnq',
#  'offici gop platform less abort war gopdeb prioriti',
#  'rt pattonoswalt kill peopl break thing huckabe describ gop gopdeb',
#  'rt sallykohn think megynkelli gopdeb hard hit question concern major voter fring gop base',
#  'ambitiouspaul skin make us brain sellout gopdeb',
#  'rt dwstweet final thought gopdeb tonight republican parti touch date http co tuegrpp',
#  'rt writeintrump gopdeb parti updat rubio cruz bush huddl corner speak spanish think plottin',
#  'rt lilagraceros megynkelli abort never medic necessari tout ppact talk point question scottwalk',
#  'rt leokapakosni break presid obama vp biden close watch gopdeb http co jsmiznwhjq',
#  'abort talk point gopdeb sinc ppsellsbabypart',
#  'real nerd fun fact check gopdeb http co un cj dotj',
#  'rt tnycloseread santorum compar scotu marriag rule dred scott analog nonsens http co xjzdnxdm',
#  'rt fredzeppelin priceless carlyfiorina clean chri matthew clock post debat woman contend gopdeb gocarli h',
#  'npr rip niloy islam ic fundamentalist must die either normal human isi irand gopdeb',
#  'rt dosta dailymail futur first famili gopdeb http co nmkfgad ei http co iwwrpsntpl',
#  'rt georgehenryw master use humor gopdeb imwithhuck gop ccot teaparti tcot makedclisten wethepeopl uniteright http',
#  'rt amymek debat opinion chang foxnew megynkelli bretbaier amp chri wallac utterli disappoint g',
# ...
#  'rt clairechansen hey trump refrain call women fat pig whore polit correct decent human',
#  'rt jessecox women less right babi gopdeb',
#  'rt adamsmith usa democrat watch gopdeb http co musuto irh',
#  'rt nicolet e megynkelli frankluntz use like anymor read tweet aw job tonight go',
#  'jeb bush proven conserv record amp proven record win gopdeb http co vn hf yem',
#  'rt samugranado robert costa david weigel break gopdeb neat present tan shelli sethblanchard http',
#  'rt hwrudulph take break gopdeb reminisc awesom groundbreak badasseri queenlatifah http c',
#  'rt thebaxterbean scott walker forc women carri rapist pregnanc amp let men sue abort gopdeb http co yzivipqanx b',
#  'rt monaeltahawi cheer shame gopdeb trump respond megyn kelli question misogyni misogyni http c',
#  'gopdeb second http co hzowuufpo',
#  'rt thebaxterbean marco rubio plan help wall street profit colleg student futur earn http co kowxcw ibc gopdeb htt',
#  'rt shannonbream donor class feed polit class govt keep get bigger say govmikehuckabe gopdeb',
#  'carlyfiorina magnific first gopdeb support ted cruz potu would support run mate potu honesti',
#  'rt einial rubio ear get bigger debat gopdeb',
#  'kasich william gopdeb http co qddoqyx ip',
#  'first gopdeb social media reaction http co sbvi iiruf',
#  'rt murphttam miss gopdeb last night fear got cover recap http co mdi jzvabp',
#  'would realli let mother die rather abort serious ask presidenti hope gopdeb',
#  'tajmagrud say gop bash hillaryclinton campaign platform gopdeb',
#  'rt danscavino icymi realdonaldtrump morn joe morningmika discuss gopdeb trump makeamericagreatagain http co',
#  'kylebrandt gopdeb fox made megynkelli play women victim profession rage b night',
#  'earli polit theater w billionair bush gore corrupt polit gopdeb trump buy em',
#  'rt realobf god next gopdeb http co tudl f zs',
#  'rt wstachelberg last night gopdeb topic merit attent ignor goptbt http co mbetsrsri',
#  'rt tinymuslimah everybodi wanna jesu freak till time feed poor gopdeb',
#  'rt johneberkowitz sum gopdeb perfectli http co p w ea',
#  'rt bbcjonsopel listen donald trump get impress could start fight empti room gopdeb',
#  'rt thefriddl miss day conserv want gop presidenti candid know conserv trump gopdeb',
#  'heard clip gopdeb nsa w christi amp paul christi support nsa past action agre w obama amp democrat right',
#  'rt tombx someon pleas tell megyn kellyfil gopdeb',
#  'next word pre bartlet gopdeb',
#  'gopdeb gopclowncar http co ed f zifi',
#  'hate miss gopdeb last night foxnew high light point',
#  'fuck last one done gopdeb chrischristi http co qamuqbetdc',
#  'rt brian mcgill fantast statist breakdown gopdeb randyyeip stuartathompson last night http co dbgl gdfpb htt',
#  'rt k mcq megyn kelli trump keep go everyon attack ye ms offend feminist go',
#  'beeteedub play lesser evil parti perhap need new parti p tcot gopdeb',
#  'two debat one winner carli http co piewa jccc carli gopdeb',
#  'rt freedomjam john kasich rino gopdeb',
#  'rt leticiaestrada anyon see last night gopdeb trump http co au dydowh',
#  'rt alicetweet come govmikehuckabe foxbusi gopdeb http co jsliardfco',
#  'rt number cat glad swimsuit round gopdeb http co titzlo',
#  'petit exclud megyn kelli host futur fox news debat http co dxnjjuxel chang gopdeb debat megynkelli gop',
#  'debat like found father http co kulhlxsk gopdeb lnyhbt tlot tcot p',
#  'therightscoop well frankluntz focu group certainli match today gopdeb poll',
#  'rt docrocktex want lead countri want make decis behalf open case',
#  'rt deray scott walker danger deep world comfort seem danger gopdeb',
#  'let pretend bar potu high somewher sh syphili gopdeb tcot',
#  'gop proud defeat teacher union even though want higher wage gopdeb',
#  'good point wait til hear seriou debat gopdeb foxnew http co ighqi lgh',
#  'rt tananarivedu shaunk point gopdeb huge audienc poc readi learn learn mostli scari',
#  'rt theblaz pundit incens megynkelli abort question scottwalk gopdeb http co hamuusrz',
#  'give fli fuck hollywood celeb think last night gopdeb know want win alreadi f',
#  'rt fakedansavag trump nomine run independ gopdeb',
#  'rt persianpolitik woodruffbet thedailybeast prove realdonaldtrump point bad journalist gopdeb ev',
#  'rt chadhastyradio realli peopl seem upset bretbaier amp megynkelli amp fox peopl back trump gopdeb',
#  'deb libbi half republican base dementia probabl found rivet confus tv w toaster gopdeb',
#  'rt marcorubio elect better futur past gopdeb',
#  'agre megynkelli mean bimbo donaldtrump woman find trump comment disgust gopdeb',
#  'rt deray christi come across bulli bulli remind hurt peopl best interest gop',
#  'chri christi tri wrap giuliani style gopdeb lie twice http co mudmr p',
#  'rt k mcq embarrass brilliant stun woman like megyn kelli use sjw feminist propaganda attack republican gopdeb',
#  'rt kerryepp debat candid candid moder moder time keeper',
#  'gopdeb politician stick old topic pro life pro choic gay marriag let go person choic',
#  'mean matter question unfair bother answer anyway realdonaldtrump gopdeb',
#  'rt peddoc go carli go carli go carli carlyfiorina carli gopdeb steph maydnusa http co pk zvk',
#  'todd palin amp rand paul close senor frog puerto vallarta togeth day rigor jet ski gopdeb',
#  'rt didikatz mistak think gopdeb would fun see deep sick us conservat becom bastard amp spawn foxnew v',
#  'gopdeb interest watch candid good point economi chang yr',
#  'debat preform kasich rubio carson b christi b trump b bush b cruz b huckabe b paul c walker c gopdeb kasich rubio',
#  'rt wnd txt trump man substanc fighter intellectu class never abl understand hand person like tru',
#  'donald trump clash megyn kelli gopdeb video http co k h czrymw',
#  'rt phillyd went gay wed applaus black peopl stand ovat gopdeb',
#  'gopdeb realdonaldtrump still twitter loos ground http co tximi soq http co cvclcb ubm',
#  'rt kumailn militari reason fuck shit gopdeb',
#  'joshtpm gopdeb http co ayxbtxwskr money buy love trump quot',
#  'rt writeintrump jeb bush refer vito corleon alway thought fredo gopdeb',
#  'rt maureenjohnson women gun peopl gopdeb',
#  'rt tamaracg new favorit gif perfect gopdeb http co ukdz av',
#  'rt wordplay day dreamdefend censor take candid actual word post kkkorgop gopdeb http',
#  'rt learjett foxnew use crazi gt dwstweet stir drama pot unprofession foxnew gopdeb julietteisabel',
#  'rt ykhong instagram took dreamdefend websit post real quot gopdeb wi http co rebyrjgck http co',
#  'rt themattfowl mr trump next question pleas explain pathet take stone cold stunner gopdeb htt',
#  'rt amymek way realdonaldtrump ever treat fairli media gt gopdeb http co wyduo v k',
#  'realdonaldtrump hire actor announc mani pay click drudg report survey gopdeb trump',
#  'rt libertyladyusa ye conservvoic kerrypicket gt megynkelli megyn disappoint gopdeb',
#  'rt theladygrantham donald trump dear middl class gopdeb',
#  'gopdeb trump trump trump realdonaldtrump biggest loser http co c gmzo via sfgate',
#  'want point one time real question real presidenti debat god say gopdeb',
#  'rt thebaxterbean marco rubio constitut right choos egregi flaw decis http co u wrh mxn gopdeb http',
#  'scott walker wisconsin see fastest shrink middl class america http co zopokedb l gopdeb votersfirst trump',
#  'support seem care corrupt politician call stupid gopdeb http co jnmnzszbk',
#  'gopdeb carli fiorina call hillari liar x hardbal chri minut later say never liar',
#  'know audienc erupt last night realdonaldtrump rosi line que could want guy prez gopdeb',
#  'winner gopdeb sen marcorubio amp former hp ceo carlyfiorina far best republican presidenti candid http co v qdpmpkk',
#  'rt nancyleegrahn gopdeb giant commerci hillaryclinton presid thank god',
#  'rt daveanthoni chewbacca roar everi would fit right gopdeb',
#  'gopdeb field seem terrifi mention obama neg light',
#  'polit correct vile term peopl invok slur coward gopdeb http co n pu zovbh',
#  'establish gopdeb afraid someon will tell truth would shake dc http co mia yswp',
#  'rt writeintrump knew war iraq bad idea like knew let blind guy cut rand paul hair bad idea gop',
#  'yay social issu next gopdeb',
#  'rt artiswarusa democrat say hail hitleri socialist deathbydemocrat elect stophillari gopdeb nazi liberallog http',
#  'rt elevat rladi hop fb saw friend recap gopdeb win http co tpszbvid',
#  'rt mammal suck shock hour gopdeb amp qs polic brutal amp blacklivesmatt',
#  'mayb tweet game know let spell contest profan u win gopdeb http co taliqmezh',
#  'rt jeffsimmon gopdeb takeaway presenc matter see presenc blend believ articul integr w edg',
#  'carli fiorina run circl around chri matthew hillari record youtub http co b p wg ixz gopdeb',
#  'rt jrehl gopdeb donald trump bruce wayn would turn parent live',
#  'rt jphoganorg gopdeb feelthebern step fallen hillari justic fbi fec dissect nd amend http',
#  'rt ali compil chart base poll rank versu time allot speak gopdeb walker paul rob http co',
#  'gop debat campaign preview rearview bradbannon linkedin http co n mko qqie uniteblu p potu gopdeb rsg',
#  'rt richardhin joe biden watch gopdeb http co axgitm',
#  'american women take note realdonaldtrump justifi piggish attack women gopdeb man stage call',
#  'rt feministabul hate abort defund plan parenthood surefir way increas abort',
#  'rt leahrboss carlyfiorina spank boy tonight even radar gopdeb',
#  'rt indranibala chri christi current use case bolster campaign presid gopdeb http co ygmuldg n',
#  'jeb look like beavi smile gopdeb',
#  'need comedi show gopdeb meanwhil macdeb kinda snore sorri canada http co qiqvu fsr',
#  'rt thebaxterbean remind famili import republican candid gay famili http co cs usassq gopdeb ht',
#  'debat like found father less like game show http co kulhlxsk gopdeb',
#  'berniesand scottwalk man say one intellig thing mean none berniesand gopdeb feelthebern',
#  'seriou gopdeb hangov today',
#  'rt cfjwagner scariest bug mean gop candid rimshot http co okc tfczww gopdeb blog writerslif http',
#  'rt marnu perfect remedi gopdeb hangov ff pharri mharvey comebackdecad glentheplumb rfschatten',
#  'realdonaldtrump got trump megynkelli gopdeb',
#  'rt mydaughtersarmi debat hard ted cruz gopdeb http co hmr num n',
#  'rt keemstarx black guy smart fuck gopdeb trump make vp',
#  'thought megynkelli awesom job gopdeb person',
#  'megynkelli u disappoint last night gopdeb u ask realdonaldtrump q pertin duti presid',
#  'rt gahtbomb mike huckabe purpos militari kill peopl break thing gopdeb',
#  'rt ag texa hillari clinton respons gopdeb guy ok secur thousand vote illeg',
#  'rt writeintrump everi time bell ring rand paul littl poodl ear keep perk gopdeb',
#  'rt whinenot rush one candid stage join megan kelli go donald trump gopdeb',
#  'rt writeintrump rand paul haircut realli distract almost yell rand get leash time walk gopdeb',
#  'tire shill media hillari henceforth known shillari gopdeb',
#  'rt almightygod ben carson god pretti fair guy guess never read bibl job pharaoh shebear gopdeb',
#  'rt writeintrump cheap tactic rand paul get haircut poodl distract gopdeb',
#  'rt theblaz mattwalshblog republican gopdeb mayb think elect someon http co brx ildwm',
#  'john kasich seem like decent guy piti republican gopdeb',
#  'gopdeb bingo atavist http co hkew f kb http co pwaoz kvop',
#  'rt rmconserv cruz line campaignconserv cut core issu gop amp also shortcom gopdeb htt',
#  'rt pulmyear offici photo big foxnew gopdeb last night http co yqgzvc qv',
#  'last night gopdeb prove everyth alreadi knew white patriarch elitist homophob parti gop',
#  'trump integr charact principl proud mattwalshblog agre gopdeb trump',
#  'rt linnyitssn also funni constitut love republican structur violat constitut bring religion polit g',
#  'rt oaaselect radic capit individu right look heroic candid gopdeb',
#  'blowtorch ir like sound criminalabusesnowpois policeourhealthcar go rick gopdeb http co zflcfhee j',
#  'rt megynkelli favorit tonight gopdeb foxnew',
#  'gopdeb fix get go first question pledg support address directli realdonaldtrump',
#  'first gopdeb social media reaction http co uh ezxxfg socialmedia smo',
#  'realbencarson excel job last night gopdeb class act around proud republican candid bencarson',
#  'rt korystamp lookup misogynist spike merriamwebst http co k rbb rlc trump women gopdeb http co yxsj',
#  'god speak looney tune real question gopdeb http co fbo cn',
#  'rt marcorubio skye go make american centuri got empow small busi thank question',
#  'rt pattonoswalt god name bruce springsteen go listen jungleland get fuck clue christi gopdeb',
#  'saw megynkelli reach scratch ball pick th fight realdonaldtrump gopdeb tcot',
#  'rt thepatriot winner overal today gopdeb carlyfiorina realli stood among gop candid',
#  'republican hate gun free zone held gopdeb gun free zone http co rlayowqw',
#  'rt peddoc embassi attack woman would trust rt carlyfiorina fav hillaryclinton gopdeb http',
#  'rt lizadonnelli polit nonsens last night gopdeb see http co mocgzthbdz site http co xyahgrr vh',
#  'rt teatraitor gopdeb still clown show glad head clown trump help destroy gop http co pri qpcwfu',
#  'must admit realdonaldtrump throw shade like rhoa lol gopdeb http co c luq dww',
#  'look forward listen drshow news roundup morn look away gopdeb http co rtitvgdt',
#  'rt molonlab us last night look megynkelli bretbaier gopdeb tcot realdonaldtrump http co k tk',
#  'know laugh cri last night gopdeb',
#  'rt pillari differ polit correct massiv jerk mr trump gopdeb',
#  'thought perri fiorina must replac paul kasich top ten jindal need step replac christi gopdeb',
#  'rt marcorubio nomine parti futur gopdeb',
#  'sentedcruz best answer night respons immigr stupid side want gopdeb',
#  'rt thebloggess rather watch gopdeb watch maureenjohnson live tweet made right decis http',
#  'interest gopdeb analysi marcorubio clearli excel conserv leader need go teammarco tcot http co pve wuodk',
#  'krauthamm sorri downfal trump last night debat greatli exagger gopdeb',
#  'moder scottwalk rip iran deal day walker rememb tie yellow ribbon tree gopdeb',
#  'rt ccalbo tell us god speak happen real life gopdeb',
#  'rt gusramsey snl big enough cast spoof gopdeb',
#  'bbcworld rt bbcjonsopel midst gopdeb came big blow barackobama announc lead jewish democrat sen schumer',
#  'rt ccalbo huckabe militari kill peopl break thing behalf militari famili f gopdeb',
#  'rt perezhilton watch gopdeb hillaryclinton take selfi kimkardashian http co hytsdemr http',
#  'rt realbencarson pre gopdeb ritual bc dc http co agbmc nbm',
#  'realdonaldtrump arrog gopdeb use law countri advantag notthatguy http co rjtjr ioac',
#  'hour later look back biggest gaff gopdeb repeatedli tag victor cruz teamvic instead ted cruz tedcruz',
#  'real scari liber allow walk around commit horrif crime human gopdeb plannedbutcherhood',
#  'like thank candid gopdeb took trump task tri fatsham rosi',
#  'gotta love megynkelli gopdeb',
#  'rt numbersmunch donald trump guy flip risk board realiz overtak asia gopdeb',
#  'brendohar great battl last night premier teenag athlet gopdeb http co plgp aai',
#  'foxnew replac megynkelli marthamaccallum futur debat maccallum much better job earli debat gopdeb',
#  'donald trump democrat spi http co n mvtkn u realdonaldtrump sensand trump donaldtrump hillari gopdeb',
#  'rt jjosephwilliam unit state home tv set tune gopdeb wow http co tr vmwjyg',
#  'gopdeb old white rich conserv dude parad childhood nightmar mine',
#  'ljcambria realdonaldtrump forget vote especislli go independ lulz huckster rnc gop gopdeb',
#  'recap gopdeb tenmen want make choic women goptbt http co v desifye',
#  'rt writeintrump made hillari clinton go wed also made best man gopdeb',
#  'rand paul could drop top w dread petul debat fiorina move gopdeb tcot',
#  'rt nerdist gotta say refresh hear presidenti debat everyon correctli pronounc nuclear gopdeb',
#  'rt gogoalee ig delet dd account particip kkkorgop hashtag gopdeb http co jnyrnopngx via dream',
#  'rt crazyclarin lol rt flyguy watch gopdeb like http co zowjcu baz',
#  'rt sjadetx thought gopdeb http co bt glnyuon',
#  'rt freedomtexasmom love megynkelli die tonight gopdeb foxnew trumpcruz makeamericagreatagain']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)

# %%
X = cv.fit_transform(corpus).toarray()
y = df['sentiment'].values
